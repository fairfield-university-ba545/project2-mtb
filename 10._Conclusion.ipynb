# %% [markdown]
# # Conclusion

# %% [markdown]
# ### Sub Questions:

# %% [markdown]
# #### 1. Which model is the best predictor for determining if a customer will make a purchase, or not, based on the  average weighted F1 score and average AUC score?
# ___
# Our top 3 models are:
# * Random Forest
# * Logistic Regression
# * XGBoost
#
# Based on the average weighted f1-scores, our top models are: <b> Random Forest </b> and <b> Logistic Regression </b>, whereby the average weighted f1-scores are not significantly different with a 95% confidence interval (p-value: 0.288) between the two models.
#
# Variance in f1-scores is lowest for Random Forest (RF) and highest for Logistic Regression (LR) with a standard deviation of RF: 0.00522, which is smaller than LR: 0.00893.
# <br> Variance in AUC scores is lowest for Logistic Regression and highest for Random Forest, with a standard deviation of LR: 0.007, which is smaller than RF: 0.0118.

# %% [markdown]
# Running TPOT (Automated Machine Learning), it is suggested that the models Random Forest and XGBoost are preferred with a different set of hyper-parameters, than we found with Gridsearch in our initial modeling phase.
# <br> But the average weighted f1-score of 0.9008 with TPOT Random Forest optimized hyper-parameters, provides little additional predictive power, relative to the f1-score of 0.8914 in our own modeling with Random Forest.
#
# The authors give preference to the model: <b> 'Random Forest' </b> due to the lower variance in the weighted f1-scores (with 10 KFold cross-validation).

# %% [markdown]
# #### 2. Is investing in Google Analytics (Bounce Rate, Exit Rate & Page Value) worth considering?
# ___

# %% [markdown]
# The short answer: <b> Yes it is! </b>
# <br> In our tested models, Page Values, Exit Rates and Bounce Rates our consistently among our top features.
# <br> Below an example of feature importance in Random Forest, whereby the Exit- and Bounce Rates are combined into a single variable (due to high correlation between the two features).
# <br> It shows that the feature 'PageValues...' accounts for almost half of the predictive power in explaining if an online shopper makes a purchase or not in a single session.
# <br> Followed by the combined feature: (ExitRates+BounceRates).

# %% [markdown]
# ![RF_pipeline2_features.PNG](attachment:RF_pipeline2_features.PNG)

# %% [markdown]
# #### 3. Which features, besides Google Analytics features, contribute most to customers’ purchasing behaviors?
# ___

# %% [markdown]
# In our models, among the features listed being important features, we found the following patterns of features worth mentioning as contributing to customer purchasing behaviors:

# %% [markdown]
# <b> Web Type </b>
# > Administrative
# <br> Product Related
#
# <b> Visitor Type </b>
# > New Visitor
#
# <b> Time period </b>
# > Quarter 3
# <br> Quarter 4
#
# <b> Traffic Type </b>
# > 1, 2, 3, 13, 15

# %% [markdown]
# #### 4. Does seasonality play a role in customer’s purchasing decision?
# ___

# %% [markdown]
# Yes, seasonality does play a role in a customers decision to buy online, especially during:
#
# <b> Quarters: </b>
# > Q3
# <br> Q4
#
# <b> Months: </b>
# > November
# <br> May
# <br> March
#
# <b> Special Day </b>
# > Close to a special day (e.g., Mother’s Day)

# %% [markdown]
# ___

# %% [markdown]
# ### Main Research Question
# _What drives potential customers to make a purchase?_

# %% [markdown]
# To answer that question, we first note that the model: <b> Random Forest </b> is our preferred model to predict if a customer is going to make a purchase or not.
# <br> We used the feature importance and found out that the main drivers are <b> PageValues </b>  and <b> Exit/Bounce Rates </b>.
# <br> Although less important, <b> Seasonality </b> plays a factor as well (especially November), as does the closeness to a <b> Special Day </b> (very close to a specific special day).

# %% [markdown]
# ### Next steps to take...

# %% [markdown]
# Future research should not remove _'outliers'_ for the feature: PageValues, as those _'outliers'_ provide additional information.
#
# Next steps to take for future research could be:
# > How to improve Administrative & Product Pages.
# <br> For pages with a high page value, utilize eye tracking on a focus group of customers, to find out why these pages have a high page value and others do not.
